# %% [markdown]
# # Summary

# %%
from proposal.export import processing_metrics
path = '\\\\wsl$\\Ubuntu-20.04\\home\\miguel97\\NPLinker_v2\\input\\VS4-2\\'
metrics = processing_metrics(path=path)
# Out:
# BGCs en el internal_map:                   262
# Spectrum en el internal_map:               2109

# %%
df = metrics.OutputFile(MaxCosSimil=True, save=True)
# Out:
# Tamaño original del archivo:               166830
# Total de BGCs en HTML:                     1748
# Total de BGCs contenidos en internal map:  232
# Tamaño del archivo filtrando los BGCs:     20196
# Tamaño del archivo resumen post promedio:  5835

# %%
# import numpy as np
# from proposal.score import fast_cosine, fast_cosine_shift
# # len(metrics.spectrum_user), len(metrics.spectrum_inter)
# spectrum_user  = metrics.spectrum_user
# spectrum_inter = metrics.spectrum_inter
# clustersum     = metrics.clustersum

# clustersum

# spectrum = np.ones([len(spectrum_user), len(spectrum_inter)])*np.nan
# specData = {}
# for n1, spec1 in enumerate(metrics.spectrum_user):
#   for n2, spec2 in enumerate(metrics.spectrum_inter):
#     spec1, spec2
#     spectrum[n1,n2] = fast_cosine(spec1, spec2, 0.2, 0)[0]
#     specData[n1,n2]

# spectrum
# Out:
#     AllGroups DefaultGroups  EvenOdd  G1  G2  G3  G4  G5  G6  \
# 0                        G4        1   0   0   0   2   0   0
# 1                        G4        1   0   0   0   2   0   0
# 2                        G4        1   0   0   0   2   0   0
# 3                        G4        1   0   0   0   2   0   0
# 4                        G4        1   0   0   0   3   0   0
# ..        ...           ...      ...  ..  ..  ..  ..  ..  ..
# 425                      G4        1   0   0   0   3   0   0
# 426                      G4        1   0   0   0   2   0   0
# 427                      G4        1   0   0   0   7   0   0
# 428                      G4        0   0   0   0   3   0   0
# 429                      G4        0   0   0   0   4   0   0
#
#                                    GNPSLinkout_Cluster  ... SpectrumID  \
# 0    https://gnps.ucsd.edu//ProteoSAFe/result.jsp?t...  ...        NaN
# 1    https://gnps.ucsd.edu//ProteoSAFe/result.jsp?t...  ...        NaN
# ...
